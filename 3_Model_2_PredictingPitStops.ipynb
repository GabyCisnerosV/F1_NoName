# %% [markdown]
# # Model Training:
# ### Part 2 >>> Predicting the number of pit stops in a race.

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://media.giphy.com/media/MovqJSMROh1gA/giphy.gif")
# Out:
# <img src="https://media.giphy.com/media/MovqJSMROh1gA/giphy.gif"/>

# %% [markdown]
# ### Notebook Summary:
#
# I try predicting the number of pit stops in a race.

# %% [markdown]
# ### 1) Importing Packages and Data

# %%
import pandas as pd
import numpy as np
import F1_Preprocessing #Internal package to preprocess data
import F1_Modelling_Extra_Functions # Internal package here used to evaluate models
import seaborn as sns
import matplotlib.pyplot as plt
from statistics import mean, stdev
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold, GridSearchCV #cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.exceptions import UndefinedMetricWarning
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from xgboost import XGBClassifier
from tensorflow.keras import backend as K,utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.metrics import Precision
from tensorflow.keras.optimizers import SGD,Adam
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
# import joblib
import warnings



np.random.seed(1994)
pd.set_option('display.max_columns', None)
plt.figure(dpi=150)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=UserWarning)

# %%
#The data stored in this path is obtained from ERGAST AND FASTF1 APIs (The files used to update and download the data are in the repo)

path = 'C:/Users/gabri/Dropbox/Gaby/Proyectos/My_Portafolio/F1/Data/'

PitsDF=pd.read_csv(path+"PitsDF.csv")
ResultsDF=pd.read_csv(path+"ResultsDF.csv")
WeatherDF=pd.read_csv(path+"FASTF1_Weather.csv") #available only from 2018
LapsDF=pd.read_csv(path+"FASTF1_Laps.csv") #FAST F1 available only from 2018, Ergast from before but does not have compound data
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_22156\3262076788.py:8: DtypeWarning: Columns (27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   LapsDF=pd.read_csv(path+"FASTF1_Laps.csv") #FAST F1 available only from 2018, Ergast from before but does not have compound data

# %% [markdown]
# ### 2) Data Preprocessing

# %%
# Apply the data preprocessing for each df using a function stored in the repo from F1_Preprocessing.py 
# This is done this way so the preprocessing is consistent throughout all notebooks.
# With this code we:
#   - create new features
#   - format dates and floats
#   - encode features
#   - null handling

ResultsDF=F1_Preprocessing.preprocess_Ergast_Results(ResultsDF,OneHotEncoder=True,HandleNulls=True)
PitsDF=F1_Preprocessing.preprocess_Ergast_Pits(PitsDF,OneHotEncoder=True)
WeatherDF=F1_Preprocessing.preprocess_FastF1_Weather(WeatherDF,OneHotEncoder=True)
LapsDF=F1_Preprocessing.preprocess_FastF1_Laps(LapsDF,OneHotEncoder=True)

from_season=2018

ResultsDF=ResultsDF[ResultsDF["season"]>=from_season]
PitsDF=PitsDF[PitsDF["season"]>=from_season]
WeatherDF=WeatherDF[WeatherDF["season"]>=from_season]
LapsDF=LapsDF[LapsDF["season"]>=from_season]

print(len(ResultsDF))
print(len(PitsDF))
print(len(WeatherDF))
print(len(LapsDF))
# Out:
# 2879
# 3861
# 70243
# 392595

# %%
#making a df with the pits in a season-round-driver level
#Deleting 7 rows where the number of pit stops is higher than 5
columns_from_original=PitsDF.drop(columns=["pit_stop_duration_in_milliseconds","pit_stop_number","pit_stop_lap_number",'pit_stop_time', 'pit_stop_duration']).columns
PitsDF=PitsDF[PitsDF["pit_stop_number"]<=4]

DF_CALCULATED=PitsDF.groupby(["season-round-driverid"]).agg(Total_Num_Pits=("pit_stop_number","max"),
                                              Total_Duration_Pits_milliseconds=("pit_stop_duration_in_milliseconds","sum"),
                                              Min_Duration_Pits_milliseconds=("pit_stop_duration_in_milliseconds","min"),
                                              Avg_Duration_Pits_milliseconds=("pit_stop_duration_in_milliseconds","mean"),
                                              Max_Duration_Pits_milliseconds=("pit_stop_duration_in_milliseconds","max"),
                                              Avg_PitStop_Lap_number=("pit_stop_lap_number","mean"),
                                              Min_PitStop_Lap_number=("pit_stop_lap_number","min"),
                                              Max_PitStop_Lap_number=("pit_stop_lap_number","max")).reset_index()

DF_PIVOT=PitsDF.pivot(index="season-round-driverid",columns=["pit_stop_number"],values=["pit_stop_lap_number","pit_stop_duration_in_milliseconds"]).reset_index()
DF_PIVOT.columns = ['_'.join(map(str, col)).strip() if isinstance(col, tuple) else col for col in DF_PIVOT.columns]
DF_PIVOT=DF_PIVOT.rename(columns={"season-round-driverid_":"season-round-driverid"})

PitsDF_RACE_DRIVER_LEVEL=DF_CALCULATED.merge(DF_PIVOT,on="season-round-driverid",how="left").merge(PitsDF[columns_from_original].drop_duplicates(),how="left")
print(len(PitsDF_RACE_DRIVER_LEVEL))
# Out:
# 2685

# %%
####################################################################################################
#Prepare weather data at the start of the race to add to PitsDF_RACE_DRIVER_LEVEL df. 
print(WeatherDF["season-round"].nunique())
WeatherDF_StartRace=WeatherDF[(WeatherDF["event_Race"]==1)].groupby(["season-round"]).agg(MinTime=("time","min")).reset_index()
WeatherDF_StartRace=WeatherDF_StartRace.merge(WeatherDF[['time', 'airtemp', 'humidity', 'pressure', 'rainfall', 'tracktemp',
                                                         'winddirection', 'windspeed', 'season-round',
                                                         'season-round-event', 'normalized_airtemp', 'normalized_humidity',
                                                         'normalized_pressure', 'normalized_rainfall', 'normalized_tracktemp',
                                                         'normalized_winddirection', 'normalized_windspeed']],
                                                         on="season-round",how="right")
WeatherDF_StartRace=WeatherDF_StartRace[WeatherDF_StartRace["MinTime"]==WeatherDF_StartRace["time"]].drop(columns=["MinTime",'time'])
print(len(WeatherDF_StartRace))

####################################################################################################
#Prepare compound data at the start of the race to add to PitsDF_RACE_DRIVER_LEVEL df. 
print(len(LapsDF[["season-round","driver"]].drop_duplicates()))
Compounds_StartRace=LapsDF[(LapsDF["event_Race"]==1)].groupby(["season-round","driver"]).agg(MinTime=("time","min")).reset_index()
Compounds_StartRace=Compounds_StartRace.merge(LapsDF[['time','driver', 'drivernumber','tyrelife', 'freshtyre','season-round', 'normalized_tyrelife', 'compound_cat',
                                                         'compound_HARD', 'compound_HYPERSOFT', 'compound_INTERMEDIATE',
                                                         'compound_MEDIUM', 'compound_SOFT', 'compound_SUPERSOFT',
                                                         'compound_TEST-UNKNOWN', 'compound_ULTRASOFT', 'compound_WET','compound', 'event']],
                                                         on=["season-round","driver"],how="right")
Compounds_StartRace=Compounds_StartRace[Compounds_StartRace["MinTime"]==Compounds_StartRace["time"]].drop(columns=["MinTime",'time'])
print(len(Compounds_StartRace))

####################################################################################################
#Prepare Results data to add to PitsDF_RACE_DRIVER_LEVEL df.
selected_features_constructor_focused=ResultsDF.loc[:, ResultsDF.columns.str.startswith("constructor.constructorid_")].columns.to_list()
selected_features_extra=["driver.code","constructor.name","driver.age_at_race","season-round-driverid"]
ResultsDF_to_pits=ResultsDF[selected_features_extra+selected_features_constructor_focused]
print(len(ResultsDF_to_pits))

####################################################################################################
#Merge with main df
PitsDF_RACE_DRIVER_LEVEL=PitsDF_RACE_DRIVER_LEVEL.merge(ResultsDF_to_pits,on="season-round-driverid",how="left")
print(len(PitsDF_RACE_DRIVER_LEVEL))

PitsDF_RACE_DRIVER_LEVEL=PitsDF_RACE_DRIVER_LEVEL.merge(WeatherDF_StartRace,on="season-round",how="left")
print(len(PitsDF_RACE_DRIVER_LEVEL))

PitsDF_RACE_DRIVER_LEVEL=PitsDF_RACE_DRIVER_LEVEL.merge(Compounds_StartRace,left_on=["season-round","driver.code"],right_on=["season-round","driver"],how="left")
print(len(PitsDF_RACE_DRIVER_LEVEL))

#####################################################################################################
# Change format and exclude empty rows:

cols=['rainfall','freshtyre', 'compound_HARD','compound_HYPERSOFT', 'compound_INTERMEDIATE', 'compound_MEDIUM','compound_SOFT', 'compound_SUPERSOFT', 'compound_TEST-UNKNOWN','compound_ULTRASOFT', 'compound_WET']
PitsDF_RACE_DRIVER_LEVEL[cols]=PitsDF_RACE_DRIVER_LEVEL[cols].astype("float")

PitsDF_RACE_DRIVER_LEVEL=PitsDF_RACE_DRIVER_LEVEL[~PitsDF_RACE_DRIVER_LEVEL["airtemp"].isna()] #keep all rows where weather data is available
PitsDF_RACE_DRIVER_LEVEL=PitsDF_RACE_DRIVER_LEVEL[~PitsDF_RACE_DRIVER_LEVEL["compound_cat"].isna()] #keep all rows where compound data is available
print(len(PitsDF_RACE_DRIVER_LEVEL))
# Out:
# 144
# 144
# 2999
# 2874
# 2879
# 2685
# 2685
# 2685
# 2357

# %%
# After the data analysis done, due to the compound data we filter the data to be from season 2019:
PitsDF_RACE_DRIVER_LEVEL=PitsDF_RACE_DRIVER_LEVEL[PitsDF_RACE_DRIVER_LEVEL["season"]>=2019]

# %%
PitsDF_RACE_DRIVER_LEVEL
# Out:
#      season-round-driverid  Total_Num_Pits  Total_Duration_Pits_milliseconds  \
# 382           201901-albon               1                           21780.0
# 383          201901-bottas               1                           22014.0
# 384           201901-gasly               1                           21269.0
# 385      201901-giovinazzi               1                           27172.0
# 386        201901-grosjean               1                           29981.0
# ...                    ...             ...                               ...
# 2680        202419-russell               1                           29327.0
# 2681          202419-sainz               1                           23963.0
# 2682         202419-stroll               1                           26399.0
# 2683        202419-tsunoda               1                           24193.0
# 2684           202419-zhou               2                           49323.0
#
#       Min_Duration_Pits_milliseconds  Avg_Duration_Pits_milliseconds  \
# 382                          21780.0                         21780.0
# 383                          22014.0                         22014.0
# 384                          21269.0                         21269.0
# 385                          27172.0                         27172.0
# 386                          29981.0                         29981.0
# ...                              ...                             ...
# 2680                         29327.0                         29327.0
# 2681                         23963.0                         23963.0
# 2682                         26399.0                         26399.0
# 2683                         24193.0                         24193.0
# 2684                         24433.0                         24661.5
#
#       Max_Duration_Pits_milliseconds  Avg_PitStop_Lap_number  \
# 382                          21780.0                    14.0
# 383                          22014.0                    23.0
# 384                          21269.0                    37.0
# 385                          27172.0                    27.0
# 386                          29981.0                    15.0
# ...                              ...                     ...
# 2680                         29327.0                    40.0
# 2681                         23963.0                    21.0
# 2682                         26399.0                    27.0
# 2683                         24193.0                    18.0
# 2684                         24890.0                    24.0
#
#       Min_PitStop_Lap_number  Max_PitStop_Lap_number  pit_stop_lap_number_1  \
# 382                       14                      14                   14.0
# 383                       23                      23                   23.0
# 384                       37                      37                   37.0
# 385                       27                      27                   27.0
# 386                       15                      15                   15.0
# ...                      ...                     ...                    ...
# 2680                      40                      40                   40.0
# 2681                      21                      21                   21.0
# 2682                      27                      27                   27.0
# 2683                      18                      18                   18.0
# 2684                      13                      35                   13.0
#
#       pit_stop_lap_number_2  pit_stop_lap_number_3  pit_stop_lap_number_4  \
# 382                     NaN                    NaN                    NaN
# 383                     NaN                    NaN                    NaN
# 384                     NaN                    NaN                    NaN
# 385                     NaN                    NaN                    NaN
# 386                     NaN                    NaN                    NaN
# ...                     ...                    ...                    ...
# 2680                    NaN                    NaN                    NaN
# 2681                    NaN                    NaN                    NaN
# 2682                    NaN                    NaN                    NaN
# 2683                    NaN                    NaN                    NaN
# 2684                   35.0                    NaN                    NaN
#
#       pit_stop_duration_in_milliseconds_1  \
# 382                               21780.0
# 383                               22014.0
# 384                               21269.0
# 385                               27172.0
# 386                               29981.0
# ...                                   ...
# 2680                              29327.0
# 2681                              23963.0
# 2682                              26399.0
# 2683                              24193.0
# 2684                              24433.0
#
#       pit_stop_duration_in_milliseconds_2  \
# 382                                   NaN
# 383                                   NaN
# 384                                   NaN
# 385                                   NaN
# 386                                   NaN
# ...                                   ...
# 2680                                  NaN
# 2681                                  NaN
# 2682                                  NaN
# 2683                                  NaN
# 2684                              24890.0
#
#       pit_stop_duration_in_milliseconds_3  \
# 382                                   NaN
# 383                                   NaN
# 384                                   NaN
# 385                                   NaN
# 386                                   NaN
# ...                                   ...
# 2680                                  NaN
# 2681                                  NaN
# 2682                                  NaN
# 2683                                  NaN
# 2684                                  NaN
#
#       pit_stop_duration_in_milliseconds_4  season  round  \
# 382                                   NaN    2019      1
# 383                                   NaN    2019      1
# 384                                   NaN    2019      1
# 385                                   NaN    2019      1
# 386                                   NaN    2019      1
# ...                                   ...     ...    ...
# 2680                                  NaN    2024     19
# 2681                                  NaN    2024     19
# 2682                                  NaN    2024     19
# 2683                                  NaN    2024     19
# 2684                                  NaN    2024     19
#
#                       racename             circuit.circuitname  \
# 382      Australian Grand Prix  Albert Park Grand Prix Circuit
# 383      Australian Grand Prix  Albert Park Grand Prix Circuit
# 384      Australian Grand Prix  Albert Park Grand Prix Circuit
# 385      Australian Grand Prix  Albert Park Grand Prix Circuit
# 386      Australian Grand Prix  Albert Park Grand Prix Circuit
# ...                        ...                             ...
# 2680  United States Grand Prix         Circuit of the Americas
# 2681  United States Grand Prix         Circuit of the Americas
# 2682  United States Grand Prix         Circuit of the Americas
# 2683  United States Grand Prix         Circuit of the Americas
# 2684  United States Grand Prix         Circuit of the Americas
#
#      circuit.location.country        date season-round  \
# 382                 Australia  2019-03-17       201901
# 383                 Australia  2019-03-17       201901
# 384                 Australia  2019-03-17       201901
# 385                 Australia  2019-03-17       201901
# 386                 Australia  2019-03-17       201901
# ...                       ...         ...          ...
# 2680                      USA  2024-10-20       202419
# 2681                      USA  2024-10-20       202419
# 2682                      USA  2024-10-20       202419
# 2683                      USA  2024-10-20       202419
# 2684                      USA  2024-10-20       202419
#
#       circuit.circuitid_albert_park  circuit.circuitid_americas  \
# 382                            True                       False
# 383                            True                       False
# 384                            True                       False
# 385                            True                       False
# 386                            True                       False
# ...                             ...                         ...
# 2680                          False                        True
# 2681                          False                        True
# 2682                          False                        True
# 2683                          False                        True
# 2684                          False                        True
#
#       circuit.circuitid_bahrain  circuit.circuitid_baku  \
# 382                       False                   False
# 383                       False                   False
# 384                       False                   False
# 385                       False                   False
# 386                       False                   False
# ...                         ...                     ...
# 2680                      False                   False
# 2681                      False                   False
# 2682                      False                   False
# 2683                      False                   False
# 2684                      False                   False
#
#       circuit.circuitid_buddh  circuit.circuitid_catalunya  \
# 382                     False                        False
# 383                     False                        False
# 384                     False                        False
# 385                     False                        False
# 386                     False                        False
# ...                       ...                          ...
# 2680                    False                        False
# 2681                    False                        False
# 2682                    False                        False
# 2683                    False                        False
# 2684                    False                        False
#
#       circuit.circuitid_hockenheimring  circuit.circuitid_hungaroring  \
# 382                              False                          False
# 383                              False                          False
# 384                              False                          False
# 385                              False                          False
# 386                              False                          False
# ...                                ...                            ...
# 2680                             False                          False
# 2681                             False                          False
# 2682                             False                          False
# 2683                             False                          False
# 2684                             False                          False
#
#       circuit.circuitid_imola  circuit.circuitid_interlagos  \
# 382                     False                         False
# 383                     False                         False
# 384                     False                         False
# 385                     False                         False
# 386                     False                         False
# ...                       ...                           ...
# 2680                    False                         False
# 2681                    False                         False
# 2682                    False                         False
# 2683                    False                         False
# 2684                    False                         False
#
#       circuit.circuitid_istanbul  circuit.circuitid_jeddah  \
# 382                        False                     False
# 383                        False                     False
# 384                        False                     False
# 385                        False                     False
# 386                        False                     False
# ...                          ...                       ...
# 2680                       False                     False
# 2681                       False                     False
# 2682                       False                     False
# 2683                       False                     False
# 2684                       False                     False
#
#       circuit.circuitid_losail  circuit.circuitid_marina_bay  \
# 382                      False                         False
# 383                      False                         False
# 384                      False                         False
# 385                      False                         False
# 386                      False                         False
# ...                        ...                           ...
# 2680                     False                         False
# 2681                     False                         False
# 2682                     False                         False
# 2683                     False                         False
# 2684                     False                         False
#
#       circuit.circuitid_miami  circuit.circuitid_monaco  \
# 382                     False                     False
# 383                     False                     False
# 384                     False                     False
# 385                     False                     False
# 386                     False                     False
# ...                       ...                       ...
# 2680                    False                     False
# 2681                    False                     False
# 2682                    False                     False
# 2683                    False                     False
# 2684                    False                     False
#
#       circuit.circuitid_monza  circuit.circuitid_mugello  \
# 382                     False                      False
# 383                     False                      False
# 384                     False                      False
# 385                     False                      False
# 386                     False                      False
# ...                       ...                        ...
# 2680                    False                      False
# 2681                    False                      False
# 2682                    False                      False
# 2683                    False                      False
# 2684                    False                      False
#
#       circuit.circuitid_nurburgring  circuit.circuitid_portimao  \
# 382                           False                       False
# 383                           False                       False
# 384                           False                       False
# 385                           False                       False
# 386                           False                       False
# ...                             ...                         ...
# 2680                          False                       False
# 2681                          False                       False
# 2682                          False                       False
# 2683                          False                       False
# 2684                          False                       False
#
#       circuit.circuitid_red_bull_ring  circuit.circuitid_ricard  \
# 382                             False                     False
# 383                             False                     False
# 384                             False                     False
# 385                             False                     False
# 386                             False                     False
# ...                               ...                       ...
# 2680                            False                     False
# 2681                            False                     False
# 2682                            False                     False
# 2683                            False                     False
# 2684                            False                     False
#
#       circuit.circuitid_rodriguez  circuit.circuitid_sepang  \
# 382                         False                     False
# 383                         False                     False
# 384                         False                     False
# 385                         False                     False
# 386                         False                     False
# ...                           ...                       ...
# 2680                        False                     False
# 2681                        False                     False
# 2682                        False                     False
# 2683                        False                     False
# 2684                        False                     False
#
#       circuit.circuitid_shanghai  circuit.circuitid_silverstone  \
# 382                        False                          False
# 383                        False                          False
# 384                        False                          False
# 385                        False                          False
# 386                        False                          False
# ...                          ...                            ...
# 2680                       False                          False
# 2681                       False                          False
# 2682                       False                          False
# 2683                       False                          False
# 2684                       False                          False
#
#       circuit.circuitid_sochi  circuit.circuitid_spa  \
# 382                     False                  False
# 383                     False                  False
# 384                     False                  False
# 385                     False                  False
# 386                     False                  False
# ...                       ...                    ...
# 2680                    False                  False
# 2681                    False                  False
# 2682                    False                  False
# 2683                    False                  False
# 2684                    False                  False
#
#       circuit.circuitid_suzuka  circuit.circuitid_valencia  \
# 382                      False                       False
# 383                      False                       False
# 384                      False                       False
# 385                      False                       False
# 386                      False                       False
# ...                        ...                         ...
# 2680                     False                       False
# 2681                     False                       False
# 2682                     False                       False
# 2683                     False                       False
# 2684                     False                       False
#
#       circuit.circuitid_vegas  circuit.circuitid_villeneuve  \
# 382                     False                         False
# 383                     False                         False
# 384                     False                         False
# 385                     False                         False
# 386                     False                         False
# ...                       ...                           ...
# 2680                    False                         False
# 2681                    False                         False
# 2682                    False                         False
# 2683                    False                         False
# 2684                    False                         False
#
#       circuit.circuitid_yas_marina  circuit.circuitid_yeongam  \
# 382                          False                      False
# 383                          False                      False
# 384                          False                      False
# 385                          False                      False
# 386                          False                      False
# ...                            ...                        ...
# 2680                         False                      False
# 2681                         False                      False
# 2682                         False                      False
# 2683                         False                      False
# 2684                         False                      False
#
#       circuit.circuitid_zandvoort  driverid_aitken  driverid_albon  \
# 382                         False            False            True
# 383                         False            False           False
# 384                         False            False           False
# 385                         False            False           False
# 386                         False            False           False
# ...                           ...              ...             ...
# 2680                        False            False           False
# 2681                        False            False           False
# 2682                        False            False           False
# 2683                        False            False           False
# 2684                        False            False           False
#
#       driverid_alonso  driverid_ambrosio  driverid_bearman  driverid_bottas  \
# 382             False              False             False            False
# 383             False              False             False             True
# 384             False              False             False            False
# 385             False              False             False            False
# 386             False              False             False            False
# ...               ...                ...               ...              ...
# 2680            False              False             False            False
# 2681            False              False             False            False
# 2682            False              False             False            False
# 2683            False              False             False            False
# 2684            False              False             False            False
#
#       driverid_brendon_hartley  driverid_bruno_senna  driverid_button  \
# 382                      False                 False            False
# 383                      False                 False            False
# 384                      False                 False            False
# 385                      False                 False            False
# 386                      False                 False            False
# ...                        ...                   ...              ...
# 2680                     False                 False            False
# 2681                     False                 False            False
# 2682                     False                 False            False
# 2683                     False                 False            False
# 2684                     False                 False            False
#
#       driverid_chilton  driverid_colapinto  driverid_de_vries  \
# 382              False               False              False
# 383              False               False              False
# 384              False               False              False
# 385              False               False              False
# 386              False               False              False
# ...                ...                 ...                ...
# 2680             False               False              False
# 2681             False               False              False
# 2682             False               False              False
# 2683             False               False              False
# 2684             False               False              False
#
#       driverid_ericsson  driverid_garde  driverid_gasly  driverid_giovinazzi  \
# 382               False           False           False                False
# 383               False           False           False                False
# 384               False           False            True                False
# 385               False           False           False                 True
# 386               False           False           False                False
# ...                 ...             ...             ...                  ...
# 2680              False           False           False                False
# 2681              False           False           False                False
# 2682              False           False           False                False
# 2683              False           False           False                False
# 2684              False           False           False                False
#
#       driverid_glock  driverid_grosjean  driverid_gutierrez  \
# 382            False              False               False
# 383            False              False               False
# 384            False              False               False
# 385            False              False               False
# 386            False               True               False
# ...              ...                ...                 ...
# 2680           False              False               False
# 2681           False              False               False
# 2682           False              False               False
# 2683           False              False               False
# 2684           False              False               False
#
#       driverid_hamilton  driverid_haryanto  driverid_hulkenberg  \
# 382               False              False                False
# 383               False              False                False
# 384               False              False                False
# 385               False              False                False
# 386               False              False                False
# ...                 ...                ...                  ...
# 2680              False              False                False
# 2681              False              False                False
# 2682              False              False                False
# 2683              False              False                False
# 2684              False              False                False
#
#       driverid_jolyon_palmer  driverid_jules_bianchi  driverid_karthikeyan  \
# 382                    False                   False                 False
# 383                    False                   False                 False
# 384                    False                   False                 False
# 385                    False                   False                 False
# 386                    False                   False                 False
# ...                      ...                     ...                   ...
# 2680                   False                   False                 False
# 2681                   False                   False                 False
# 2682                   False                   False                 False
# 2683                   False                   False                 False
# 2684                   False                   False                 False
#
#       driverid_kevin_magnussen  driverid_kobayashi  driverid_kovalainen  \
# 382                      False               False                False
# 383                      False               False                False
# 384                      False               False                False
# 385                      False               False                False
# 386                      False               False                False
# ...                        ...                 ...                  ...
# 2680                     False               False                False
# 2681                     False               False                False
# 2682                     False               False                False
# 2683                     False               False                False
# 2684                     False               False                False
#
#       driverid_kubica  driverid_kvyat  driverid_latifi  driverid_lawson  \
# 382             False           False            False            False
# 383             False           False            False            False
# 384             False           False            False            False
# 385             False           False            False            False
# 386             False           False            False            False
# ...               ...             ...              ...              ...
# 2680            False           False            False            False
# 2681            False           False            False            False
# 2682            False           False            False            False
# 2683            False           False            False            False
# 2684            False           False            False            False
#
#       driverid_leclerc  driverid_maldonado  driverid_massa  \
# 382              False               False           False
# 383              False               False           False
# 384              False               False           False
# 385              False               False           False
# 386              False               False           False
# ...                ...                 ...             ...
# 2680             False               False           False
# 2681             False               False           False
# 2682             False               False           False
# 2683             False               False           False
# 2684             False               False           False
#
#       driverid_max_verstappen  driverid_mazepin  driverid_merhi  \
# 382                     False             False           False
# 383                     False             False           False
# 384                     False             False           False
# 385                     False             False           False
# 386                     False             False           False
# ...                       ...               ...             ...
# 2680                    False             False           False
# 2681                    False             False           False
# 2682                    False             False           False
# 2683                    False             False           False
# 2684                    False             False           False
#
#       driverid_michael_schumacher  driverid_mick_schumacher  driverid_nasr  \
# 382                         False                     False          False
# 383                         False                     False          False
# 384                         False                     False          False
# 385                         False                     False          False
# 386                         False                     False          False
# ...                           ...                       ...            ...
# 2680                        False                     False          False
# 2681                        False                     False          False
# 2682                        False                     False          False
# 2683                        False                     False          False
# 2684                        False                     False          False
#
#       driverid_norris  driverid_ocon  driverid_perez  driverid_petrov  \
# 382             False          False           False            False
# 383             False          False           False            False
# 384             False          False           False            False
# 385             False          False           False            False
# 386             False          False           False            False
# ...               ...            ...             ...              ...
# 2680            False          False           False            False
# 2681            False          False           False            False
# 2682            False          False           False            False
# 2683            False          False           False            False
# 2684            False          False           False            False
#
#       driverid_piastri  driverid_pic  driverid_pietro_fittipaldi  \
# 382              False         False                       False
# 383              False         False                       False
# 384              False         False                       False
# 385              False         False                       False
# 386              False         False                       False
# ...                ...           ...                         ...
# 2680             False         False                       False
# 2681             False         False                       False
# 2682             False         False                       False
# 2683             False         False                       False
# 2684             False         False                       False
#
#       driverid_raikkonen  driverid_resta  driverid_ricciardo  driverid_rosa  \
# 382                False           False               False          False
# 383                False           False               False          False
# 384                False           False               False          False
# 385                False           False               False          False
# 386                False           False               False          False
# ...                  ...             ...                 ...            ...
# 2680               False           False               False          False
# 2681               False           False               False          False
# 2682               False           False               False          False
# 2683               False           False               False          False
# 2684               False           False               False          False
#
#       driverid_rosberg  driverid_rossi  driverid_russell  driverid_sainz  \
# 382              False           False             False           False
# 383              False           False             False           False
# 384              False           False             False           False
# 385              False           False             False           False
# 386              False           False             False           False
# ...                ...             ...               ...             ...
# 2680             False           False              True           False
# 2681             False           False             False            True
# 2682             False           False             False           False
# 2683             False           False             False           False
# 2684             False           False             False           False
#
#       driverid_sargeant  driverid_sirotkin  driverid_stevens  driverid_stroll  \
# 382               False              False             False            False
# 383               False              False             False            False
# 384               False              False             False            False
# 385               False              False             False            False
# 386               False              False             False            False
# ...                 ...                ...               ...              ...
# 2680              False              False             False            False
# 2681              False              False             False            False
# 2682              False              False             False             True
# 2683              False              False             False            False
# 2684              False              False             False            False
#
#       driverid_sutil  driverid_tsunoda  driverid_vandoorne  driverid_vergne  \
# 382            False             False               False            False
# 383            False             False               False            False
# 384            False             False               False            False
# 385            False             False               False            False
# 386            False             False               False            False
# ...              ...               ...                 ...              ...
# 2680           False             False               False            False
# 2681           False             False               False            False
# 2682           False             False               False            False
# 2683           False              True               False            False
# 2684           False             False               False            False
#
#       driverid_vettel  driverid_webber  driverid_wehrlein  driverid_zhou  \
# 382             False            False              False          False
# 383             False            False              False          False
# 384             False            False              False          False
# 385             False            False              False          False
# 386             False            False              False          False
# ...               ...              ...                ...            ...
# 2680            False            False              False          False
# 2681            False            False              False          False
# 2682            False            False              False          False
# 2683            False            False              False          False
# 2684            False            False              False           True
#
#      circuit.circuitid    driverid driver.code constructor.name  \
# 382        albert_park       albon         ALB       Toro Rosso
# 383        albert_park      bottas         BOT         Mercedes
# 384        albert_park       gasly         GAS         Red Bull
# 385        albert_park  giovinazzi         GIO       Alfa Romeo
# 386        albert_park    grosjean         GRO     Haas F1 Team
# ...                ...         ...         ...              ...
# 2680          americas     russell         RUS         Mercedes
# 2681          americas       sainz         SAI          Ferrari
# 2682          americas      stroll         STR     Aston Martin
# 2683          americas     tsunoda         TSU       RB F1 Team
# 2684          americas        zhou         ZHO           Sauber
#
#       driver.age_at_race  constructor.constructorid_alfa  \
# 382                   22                           False
# 383                   29                           False
# 384                   23                           False
# 385                   25                            True
# 386                   32                           False
# ...                  ...                             ...
# 2680                  26                           False
# 2681                  30                           False
# 2682                  25                           False
# 2683                  24                           False
# 2684                  25                           False
#
#       constructor.constructorid_alphatauri  constructor.constructorid_alpine  \
# 382                                  False                             False
# 383                                  False                             False
# 384                                  False                             False
# 385                                  False                             False
# 386                                  False                             False
# ...                                    ...                               ...
# 2680                                 False                             False
# 2681                                 False                             False
# 2682                                 False                             False
# 2683                                 False                             False
# 2684                                 False                             False
#
#       constructor.constructorid_aston_martin  constructor.constructorid_bar  \
# 382                                    False                          False
# 383                                    False                          False
# 384                                    False                          False
# 385                                    False                          False
# 386                                    False                          False
# ...                                      ...                            ...
# 2680                                   False                          False
# 2681                                   False                          False
# 2682                                    True                          False
# 2683                                   False                          False
# 2684                                   False                          False
#
#       constructor.constructorid_bmw_sauber  constructor.constructorid_brawn  \
# 382                                  False                            False
# 383                                  False                            False
# 384                                  False                            False
# 385                                  False                            False
# 386                                  False                            False
# ...                                    ...                              ...
# 2680                                 False                            False
# 2681                                 False                            False
# 2682                                 False                            False
# 2683                                 False                            False
# 2684                                 False                            False
#
#       constructor.constructorid_caterham  constructor.constructorid_ferrari  \
# 382                                False                              False
# 383                                False                              False
# 384                                False                              False
# 385                                False                              False
# 386                                False                              False
# ...                                  ...                                ...
# 2680                               False                              False
# 2681                               False                               True
# 2682                               False                              False
# 2683                               False                              False
# 2684                               False                              False
#
#       constructor.constructorid_force_india  constructor.constructorid_haas  \
# 382                                   False                           False
# 383                                   False                           False
# 384                                   False                           False
# 385                                   False                           False
# 386                                   False                            True
# ...                                     ...                             ...
# 2680                                  False                           False
# 2681                                  False                           False
# 2682                                  False                           False
# 2683                                  False                           False
# 2684                                  False                           False
#
#       constructor.constructorid_honda  constructor.constructorid_hrt  \
# 382                             False                          False
# 383                             False                          False
# 384                             False                          False
# 385                             False                          False
# 386                             False                          False
# ...                               ...                            ...
# 2680                            False                          False
# 2681                            False                          False
# 2682                            False                          False
# 2683                            False                          False
# 2684                            False                          False
#
#       constructor.constructorid_jaguar  constructor.constructorid_jordan  \
# 382                              False                             False
# 383                              False                             False
# 384                              False                             False
# 385                              False                             False
# 386                              False                             False
# ...                                ...                               ...
# 2680                             False                             False
# 2681                             False                             False
# 2682                             False                             False
# 2683                             False                             False
# 2684                             False                             False
#
#       constructor.constructorid_lotus_f1  \
# 382                                False
# 383                                False
# 384                                False
# 385                                False
# 386                                False
# ...                                  ...
# 2680                               False
# 2681                               False
# 2682                               False
# 2683                               False
# 2684                               False
#
#       constructor.constructorid_lotus_racing  constructor.constructorid_manor  \
# 382                                    False                            False
# 383                                    False                            False
# 384                                    False                            False
# 385                                    False                            False
# 386                                    False                            False
# ...                                      ...                              ...
# 2680                                   False                            False
# 2681                                   False                            False
# 2682                                   False                            False
# 2683                                   False                            False
# 2684                                   False                            False
#
#       constructor.constructorid_marussia  constructor.constructorid_mclaren  \
# 382                                False                              False
# 383                                False                              False
# 384                                False                              False
# 385                                False                              False
# 386                                False                              False
# ...                                  ...                                ...
# 2680                               False                              False
# 2681                               False                              False
# 2682                               False                              False
# 2683                               False                              False
# 2684                               False                              False
#
#       constructor.constructorid_mercedes  constructor.constructorid_mf1  \
# 382                                False                          False
# 383                                 True                          False
# 384                                False                          False
# 385                                False                          False
# 386                                False                          False
# ...                                  ...                            ...
# 2680                                True                          False
# 2681                               False                          False
# 2682                               False                          False
# 2683                               False                          False
# 2684                               False                          False
#
#       constructor.constructorid_minardi  \
# 382                               False
# 383                               False
# 384                               False
# 385                               False
# 386                               False
# ...                                 ...
# 2680                              False
# 2681                              False
# 2682                              False
# 2683                              False
# 2684                              False
#
#       constructor.constructorid_racing_point  constructor.constructorid_rb  \
# 382                                    False                         False
# 383                                    False                         False
# 384                                    False                         False
# 385                                    False                         False
# 386                                    False                         False
# ...                                      ...                           ...
# 2680                                   False                         False
# 2681                                   False                         False
# 2682                                   False                         False
# 2683                                   False                          True
# 2684                                   False                         False
#
#       constructor.constructorid_red_bull  constructor.constructorid_renault  \
# 382                                False                              False
# 383                                False                              False
# 384                                 True                              False
# 385                                False                              False
# 386                                False                              False
# ...                                  ...                                ...
# 2680                               False                              False
# 2681                               False                              False
# 2682                               False                              False
# 2683                               False                              False
# 2684                               False                              False
#
#       constructor.constructorid_sauber  constructor.constructorid_spyker  \
# 382                              False                             False
# 383                              False                             False
# 384                              False                             False
# 385                              False                             False
# 386                              False                             False
# ...                                ...                               ...
# 2680                             False                             False
# 2681                             False                             False
# 2682                             False                             False
# 2683                             False                             False
# 2684                              True                             False
#
#       constructor.constructorid_spyker_mf1  \
# 382                                  False
# 383                                  False
# 384                                  False
# 385                                  False
# 386                                  False
# ...                                    ...
# 2680                                 False
# 2681                                 False
# 2682                                 False
# 2683                                 False
# 2684                                 False
#
#       constructor.constructorid_super_aguri  \
# 382                                   False
# 383                                   False
# 384                                   False
# 385                                   False
# 386                                   False
# ...                                     ...
# 2680                                  False
# 2681                                  False
# 2682                                  False
# 2683                                  False
# 2684                                  False
#
#       constructor.constructorid_toro_rosso  constructor.constructorid_toyota  \
# 382                                   True                             False
# 383                                  False                             False
# 384                                  False                             False
# 385                                  False                             False
# 386                                  False                             False
# ...                                    ...                               ...
# 2680                                 False                             False
# 2681                                 False                             False
# 2682                                 False                             False
# 2683                                 False                             False
# 2684                                 False                             False
#
#       constructor.constructorid_virgin  constructor.constructorid_williams  \
# 382                              False                               False
# 383                              False                               False
# 384                              False                               False
# 385                              False                               False
# 386                              False                               False
# ...                                ...                                 ...
# 2680                             False                               False
# 2681                             False                               False
# 2682                             False                               False
# 2683                             False                               False
# 2684                             False                               False
#
#       airtemp  humidity  pressure  rainfall  tracktemp  winddirection  \
# 382      23.2      72.2    1015.5       0.0       42.9            237
# 383      23.2      72.2    1015.5       0.0       42.9            237
# 384      23.2      72.2    1015.5       0.0       42.9            237
# 385      23.2      72.2    1015.5       0.0       42.9            237
# 386      23.2      72.2    1015.5       0.0       42.9            237
# ...       ...       ...       ...       ...        ...            ...
# 2680     26.8      41.0    1008.0       0.0       44.7            105
# 2681     26.8      41.0    1008.0       0.0       44.7            105
# 2682     26.8      41.0    1008.0       0.0       44.7            105
# 2683     26.8      41.0    1008.0       0.0       44.7            105
# 2684     26.8      41.0    1008.0       0.0       44.7            105
#
#       windspeed season-round-event  normalized_airtemp  normalized_humidity  \
# 382         0.9        201901-Race            0.506369             0.740513
# 383         0.9        201901-Race            0.506369             0.740513
# 384         0.9        201901-Race            0.506369             0.740513
# 385         0.9        201901-Race            0.506369             0.740513
# 386         0.9        201901-Race            0.506369             0.740513
# ...         ...                ...                 ...                  ...
# 2680        1.1        202419-Race            0.621019             0.420513
# 2681        1.1        202419-Race            0.621019             0.420513
# 2682        1.1        202419-Race            0.621019             0.420513
# 2683        1.1        202419-Race            0.621019             0.420513
# 2684        1.1        202419-Race            0.621019             0.420513
#
#       normalized_pressure  normalized_rainfall  normalized_tracktemp  \
# 382              0.954491                  0.0              0.640299
# 383              0.954491                  0.0              0.640299
# 384              0.954491                  0.0              0.640299
# 385              0.954491                  0.0              0.640299
# 386              0.954491                  0.0              0.640299
# ...                   ...                  ...                   ...
# 2680             0.924285                  0.0              0.667164
# 2681             0.924285                  0.0              0.667164
# 2682             0.924285                  0.0              0.667164
# 2683             0.924285                  0.0              0.667164
# 2684             0.924285                  0.0              0.667164
#
#       normalized_winddirection  normalized_windspeed driver  drivernumber  \
# 382                   0.772222              0.089109    ALB            23
# 383                   0.772222              0.089109    BOT            77
# 384                   0.772222              0.089109    GAS            10
# 385                   0.772222              0.089109    GIO            99
# 386                   0.772222              0.089109    GRO             8
# ...                        ...                   ...    ...           ...
# 2680                  0.527778              0.108911    RUS            63
# 2681                  0.527778              0.108911    SAI            55
# 2682                  0.527778              0.108911    STR            18
# 2683                  0.527778              0.108911    TSU            22
# 2684                  0.527778              0.108911    ZHO            24
#
#       tyrelife  freshtyre  normalized_tyrelife  compound_cat  compound_HARD  \
# 382        1.0        1.0             0.000000           4.0            0.0
# 383        4.0        0.0             0.038961           4.0            0.0
# 384        1.0        1.0             0.000000           5.0            0.0
# 385        1.0        1.0             0.000000           5.0            0.0
# 386        4.0        0.0             0.038961           4.0            0.0
# ...        ...        ...                  ...           ...            ...
# 2680       1.0        1.0             0.000000           6.0            1.0
# 2681       1.0        1.0             0.000000           5.0            0.0
# 2682       2.0        0.0             0.012987           6.0            1.0
# 2683       1.0        1.0             0.000000           5.0            0.0
# 2684       1.0        0.0             0.000000           5.0            0.0
#
#       compound_HYPERSOFT  compound_INTERMEDIATE  compound_MEDIUM  \
# 382                  0.0                    0.0              0.0
# 383                  0.0                    0.0              0.0
# 384                  0.0                    0.0              1.0
# 385                  0.0                    0.0              1.0
# 386                  0.0                    0.0              0.0
# ...                  ...                    ...              ...
# 2680                 0.0                    0.0              0.0
# 2681                 0.0                    0.0              1.0
# 2682                 0.0                    0.0              0.0
# 2683                 0.0                    0.0              1.0
# 2684                 0.0                    0.0              1.0
#
#       compound_SOFT  compound_SUPERSOFT  compound_TEST-UNKNOWN  \
# 382             1.0                 0.0                    0.0
# 383             1.0                 0.0                    0.0
# 384             0.0                 0.0                    0.0
# 385             0.0                 0.0                    0.0
# 386             1.0                 0.0                    0.0
# ...             ...                 ...                    ...
# 2680            0.0                 0.0                    0.0
# 2681            0.0                 0.0                    0.0
# 2682            0.0                 0.0                    0.0
# 2683            0.0                 0.0                    0.0
# 2684            0.0                 0.0                    0.0
#
#       compound_ULTRASOFT  compound_WET compound event
# 382                  0.0           0.0     SOFT  Race
# 383                  0.0           0.0     SOFT  Race
# 384                  0.0           0.0   MEDIUM  Race
# 385                  0.0           0.0   MEDIUM  Race
# 386                  0.0           0.0     SOFT  Race
# ...                  ...           ...      ...   ...
# 2680                 0.0           0.0     HARD  Race
# 2681                 0.0           0.0   MEDIUM  Race
# 2682                 0.0           0.0     HARD  Race
# 2683                 0.0           0.0   MEDIUM  Race
# 2684                 0.0           0.0   MEDIUM  Race
#
# [2284 rows x 199 columns]

# %% [markdown]
# ### 3) Models

# %% [markdown]
# #### A. Predict Number of Pit stops
# ##### 1. Random Forest Classifier

# %%
# SPLIT TRAIN, VALIDATION AND TEST DFs
# I want to predict with the final_position of the last F1 rounds
EXCLUDED_COLS=['Total_Duration_Pits_milliseconds', 'Min_Duration_Pits_milliseconds','Avg_Duration_Pits_milliseconds', 'Max_Duration_Pits_milliseconds','Avg_PitStop_Lap_number', 'Min_PitStop_Lap_number',
       'Max_PitStop_Lap_number', 'pit_stop_lap_number_1','pit_stop_lap_number_2', 'pit_stop_lap_number_3','pit_stop_lap_number_4', 'pit_stop_duration_in_milliseconds_1','pit_stop_duration_in_milliseconds_2','pit_stop_duration_in_milliseconds_3','pit_stop_duration_in_milliseconds_4','season','round',
       'airtemp', 'humidity', 'pressure','rainfall', 'tracktemp', 'winddirection', 'windspeed','season-round-event','season-round-driverid', 'racename', 'circuit.circuitname','circuit.location.country', 'date', 'season-round', 'circuit.circuitid',
       'driverid', 'driver.code', 'constructor.name', 'driver', 'compound','event','compound_cat','drivernumber','tyrelife']
TEST_SEGMENTS=np.sort(PitsDF_RACE_DRIVER_LEVEL["season-round"].unique())[-15:]
TEST_DF=PitsDF_RACE_DRIVER_LEVEL[PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)
TRAINING_VALIDATION_DF=PitsDF_RACE_DRIVER_LEVEL[~PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)

print("Test DF:",len(TEST_DF))
print("Train Validation DF:",len(TRAINING_VALIDATION_DF))

TARGET='Total_Num_Pits'
X = TRAINING_VALIDATION_DF.drop(columns=[TARGET])
y = TRAINING_VALIDATION_DF[TARGET]

X_test = TEST_DF.drop(columns=[TARGET])
y_test = TEST_DF[TARGET]
# Out:
# Test DF: 290
# Train Validation DF: 1994

# %%
# CROSS VALIDATION AND HYPERPARAMETER TUNING
# RESULTS SHOWN WITH PERSONALIZED FUNCTIONS
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1994) #K FOLD STRATIFIED TO HAVE SAME TARGET DISTRIBUTION IN ALL SPLITS
model = RandomForestClassifier()

scoring = {'accuracy': 'accuracy',
           'f1_macro':'f1_macro'}

param_grid = {
    'max_depth': [5,10,15,20],
    # 'min_samples_split': [5,10,15],
    'min_samples_leaf': [5,10,20,30,40]
    }

grid_search = GridSearchCV(estimator=model, param_grid=param_grid,scoring=scoring, cv=skf, refit='f1_macro', return_train_score=True)
grid_search.fit(X, y)

cv_results,best_model=F1_Modelling_Extra_Functions.grid_search_show_results(gs=grid_search,
                                                                            X_df=X,
                                                                            feature_importance_num_features=30,
                                                                            figuresize=(15,7))
# Out:
# c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# Best Estimator:  RandomForestClassifier(max_depth=20, min_samples_leaf=5)
# Best Score:  0.3283819044362287

# %%
# Try model in test set
y_pred = best_model.predict(X_test)

# Metrics
test_accuracy = accuracy_score(y_test, y_pred)
test_f1 = f1_score(y_test, y_pred, average='macro')

# Print the results
print("Accuracy: ",test_accuracy)
print("F1-Score: ",test_f1)

F1_Modelling_Extra_Functions.classification_test_results(y_test,y_pred,figuresize=(5,3)) #confusion matrix and classification report
# Out:
# Accuracy:  0.6551724137931034
# F1-Score:  0.2595056179775281
#               precision    recall  f1-score   support
#
#            1       0.67      0.94      0.78       186
#            2       0.52      0.17      0.26        94
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.66       290
#    macro avg       0.30      0.28      0.26       290
# weighted avg       0.60      0.66      0.58       290

# %% [markdown]
# ##### 2. Random Forest Classifier (PCA)

# %%
# SPLIT TRAIN, VALIDATION AND TEST DFs
# I want to predict with the final_position of the last F1 rounds
EXCLUDED_COLS=['Total_Duration_Pits_milliseconds', 'Min_Duration_Pits_milliseconds','Avg_Duration_Pits_milliseconds', 'Max_Duration_Pits_milliseconds','Avg_PitStop_Lap_number', 'Min_PitStop_Lap_number',
       'Max_PitStop_Lap_number', 'pit_stop_lap_number_1','pit_stop_lap_number_2', 'pit_stop_lap_number_3','pit_stop_lap_number_4', 'pit_stop_duration_in_milliseconds_1','pit_stop_duration_in_milliseconds_2','pit_stop_duration_in_milliseconds_3','pit_stop_duration_in_milliseconds_4','season','round',
       'airtemp', 'humidity', 'pressure','rainfall', 'tracktemp', 'winddirection', 'windspeed','season-round-event','season-round-driverid', 'racename', 'circuit.circuitname','circuit.location.country', 'date', 'season-round', 'circuit.circuitid',
       'driverid', 'driver.code', 'constructor.name', 'driver', 'compound','event','compound_cat','drivernumber','tyrelife']
TEST_SEGMENTS=np.sort(PitsDF_RACE_DRIVER_LEVEL["season-round"].unique())[-15:]
TEST_DF=PitsDF_RACE_DRIVER_LEVEL[PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)
TRAINING_VALIDATION_DF=PitsDF_RACE_DRIVER_LEVEL[~PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)

print("Test DF:",len(TEST_DF))
print("Train Validation DF:",len(TRAINING_VALIDATION_DF))

TARGET='Total_Num_Pits'
X = TRAINING_VALIDATION_DF.drop(columns=[TARGET])
y = TRAINING_VALIDATION_DF[TARGET]

X_test = TEST_DF.drop(columns=[TARGET])
y_test = TEST_DF[TARGET]

scaler = preprocessing.StandardScaler()
X_SCALED = scaler.fit_transform(X)
X_test_SCALED = scaler.transform(X_test)

# Apply PCA
pca = PCA(n_components=16)  
X_pca = pca.fit_transform(X)
X_test_pca = pca.transform(X_test)

np.set_printoptions(suppress=True)
print('Explained variability per principal component (top 10): {}'.format(pca.explained_variance_ratio_[:10]))
print('All principal components hold: {} of the information'.format(sum(pca.explained_variance_ratio_)))

num_components = X_pca.shape[1]
column_names = [f'PC{i+1}' for i in range(num_components)] 
X_pca_df = pd.DataFrame(X_pca, columns=column_names)
X_test_pca_df = pd.DataFrame(X_test_pca, columns=column_names)
# Out:
# Test DF: 290
# Train Validation DF: 1994
# Explained variability per principal component (top 10): [0.89048984 0.01301541 0.00656269 0.00439432 0.00405852 0.0039552
#  0.00379611 0.00353354 0.00333732 0.00318264]
# All principal components hold: 0.9513602574333097 of the information

# %%
# CROSS VALIDATION AND HYPERPARAMETER TUNING
# RESULTS SHOWN WITH PERSONALIZED FUNCTIONS
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1994) #K FOLD STRATIFIED TO HAVE SAME TARGET DISTRIBUTION IN ALL SPLITS
model = RandomForestClassifier()

scoring = {'accuracy': 'accuracy',
           'f1_macro':'f1_macro'}

param_grid = {
    'max_depth': [5,10,15,20],
    # 'min_samples_split': [5,10,15],
    'min_samples_leaf': [5,10,20,30,40]
    }

grid_search = GridSearchCV(estimator=model, param_grid=param_grid,scoring=scoring, cv=skf, refit='f1_macro', return_train_score=True)
grid_search.fit(X_pca_df, y)

cv_results,best_model=F1_Modelling_Extra_Functions.grid_search_show_results(gs=grid_search,
                                                                            X_df=X_pca_df,
                                                                            feature_importance_num_features=0,
                                                                            figuresize=(15,7))
# Out:
# c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# Best Estimator:  RandomForestClassifier(max_depth=15, min_samples_leaf=10)
# Best Score:  0.30801116450359783
# -------------------------------------------------------------------------------------

# %%
# Try model in test set
y_pred = best_model.predict(X_test_pca_df)

# Metrics
test_accuracy = accuracy_score(y_test, y_pred)
test_f1 = f1_score(y_test, y_pred, average='macro')

# Print the results
print("Accuracy: ",test_accuracy)
print("F1-Score: ",test_f1)

F1_Modelling_Extra_Functions.classification_test_results(y_test,y_pred,figuresize=(5,3)) #confusion matrix and classification report
# Out:
# Accuracy:  0.6517241379310345
# F1-Score:  0.28834045860862806
#               precision    recall  f1-score   support
#
#            1       0.69      0.85      0.77       186
#            2       0.49      0.32      0.39        94
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.65       290
#    macro avg       0.30      0.29      0.29       290
# weighted avg       0.60      0.65      0.62       290

# %% [markdown]
# ##### 3. Support Vector Machines

# %%
# SPLIT TRAIN, VALIDATION AND TEST DFs
# I want to predict with the final_position of the last F1 rounds
EXCLUDED_COLS=['Total_Duration_Pits_milliseconds', 'Min_Duration_Pits_milliseconds','Avg_Duration_Pits_milliseconds', 'Max_Duration_Pits_milliseconds','Avg_PitStop_Lap_number', 'Min_PitStop_Lap_number',
       'Max_PitStop_Lap_number', 'pit_stop_lap_number_1','pit_stop_lap_number_2', 'pit_stop_lap_number_3','pit_stop_lap_number_4', 'pit_stop_duration_in_milliseconds_1','pit_stop_duration_in_milliseconds_2','pit_stop_duration_in_milliseconds_3','pit_stop_duration_in_milliseconds_4','season','round',
       'airtemp', 'humidity', 'pressure','rainfall', 'tracktemp', 'winddirection', 'windspeed','season-round-event','season-round-driverid', 'racename', 'circuit.circuitname','circuit.location.country', 'date', 'season-round', 'circuit.circuitid',
       'driverid', 'driver.code', 'constructor.name', 'driver', 'compound','event','compound_cat','drivernumber','tyrelife']
TEST_SEGMENTS=np.sort(PitsDF_RACE_DRIVER_LEVEL["season-round"].unique())[-15:]
TEST_DF=PitsDF_RACE_DRIVER_LEVEL[PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)
TRAINING_VALIDATION_DF=PitsDF_RACE_DRIVER_LEVEL[~PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)

print("Test DF:",len(TEST_DF))
print("Train Validation DF:",len(TRAINING_VALIDATION_DF))

TARGET='Total_Num_Pits'
X = TRAINING_VALIDATION_DF.drop(columns=[TARGET])
y = TRAINING_VALIDATION_DF[TARGET]

X_test = TEST_DF.drop(columns=[TARGET])
y_test = TEST_DF[TARGET]
# Out:
# Test DF: 290
# Train Validation DF: 1994

# %%
# CROSS VALIDATION AND HYPERPARAMETER TUNING
# RESULTS SHOWN WITH PERSONALIZED FUNCTIONS
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1994) #K FOLD STRATIFIED TO HAVE SAME TARGET DISTRIBUTION IN ALL SPLITS
model = SVC(class_weight='balanced')

scoring = {'accuracy': 'accuracy',
           'f1_macro':'f1_macro'}

param_grid = {
    'C': [0.01,0.1 ,1, 10, 100],  
    'kernel': ['linear', 'rbf','poly'], 
    'gamma': ['scale', 'auto']
}

grid_search = GridSearchCV(estimator=model, param_grid=param_grid,scoring=scoring, cv=skf, refit='f1_macro', return_train_score=True)
grid_search.fit(X_pca_df, y)

cv_results,best_model=F1_Modelling_Extra_Functions.grid_search_show_results(gs=grid_search,
                                                                            X_df=X_pca_df,
                                                                            feature_importance_num_features=0,
                                                                            figuresize=(15,7))
# Out:
# c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# Best Estimator:  SVC(C=100, class_weight='balanced', gamma='auto')
# Best Score:  0.2902827601275931
# -------------------------------------------------------------------------------------

# %%
# Try model in test set
y_pred = best_model.predict(X_test_pca_df)

# Metrics
test_accuracy = accuracy_score(y_test, y_pred)
test_f1 = f1_score(y_test, y_pred, average='macro')

# Print the results
print("Accuracy: ",test_accuracy)
print("F1-Score: ",test_f1)

F1_Modelling_Extra_Functions.classification_test_results(y_test,y_pred,figuresize=(5,3)) #confusion matrix and classification report
# Out:
# Accuracy:  0.5379310344827586
# F1-Score:  0.26377369224780667
#               precision    recall  f1-score   support
#
#            1       0.66      0.64      0.65       186
#            2       0.42      0.39      0.41        94
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.54       290
#    macro avg       0.27      0.26      0.26       290
# weighted avg       0.56      0.54      0.55       290

# %% [markdown]
# ##### 4. XGBoost

# %%
# SPLIT TRAIN, VALIDATION AND TEST DFs
# I want to predict with the final_position of the last F1 rounds
EXCLUDED_COLS=['Total_Duration_Pits_milliseconds', 'Min_Duration_Pits_milliseconds','Avg_Duration_Pits_milliseconds', 'Max_Duration_Pits_milliseconds','Avg_PitStop_Lap_number', 'Min_PitStop_Lap_number',
       'Max_PitStop_Lap_number', 'pit_stop_lap_number_1','pit_stop_lap_number_2', 'pit_stop_lap_number_3','pit_stop_lap_number_4', 'pit_stop_duration_in_milliseconds_1','pit_stop_duration_in_milliseconds_2','pit_stop_duration_in_milliseconds_3','pit_stop_duration_in_milliseconds_4','season','round',
       'airtemp', 'humidity', 'pressure','rainfall', 'tracktemp', 'winddirection', 'windspeed','season-round-event','season-round-driverid', 'racename', 'circuit.circuitname','circuit.location.country', 'date', 'season-round', 'circuit.circuitid',
       'driverid', 'driver.code', 'constructor.name', 'driver', 'compound','event','compound_cat','drivernumber','tyrelife']
TEST_SEGMENTS=np.sort(PitsDF_RACE_DRIVER_LEVEL["season-round"].unique())[-15:]
TEST_DF=PitsDF_RACE_DRIVER_LEVEL[PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)
TRAINING_VALIDATION_DF=PitsDF_RACE_DRIVER_LEVEL[~PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)

print("Test DF:",len(TEST_DF))
print("Train Validation DF:",len(TRAINING_VALIDATION_DF))

TARGET='Total_Num_Pits'
X = TRAINING_VALIDATION_DF.drop(columns=[TARGET])
y = TRAINING_VALIDATION_DF[TARGET]-1

X_test = TEST_DF.drop(columns=[TARGET])
y_test = TEST_DF[TARGET]-1
# Out:
# Test DF: 290
# Train Validation DF: 1994

# %%
# CROSS VALIDATION AND HYPERPARAMETER TUNING
# RESULTS SHOWN WITH PERSONALIZED FUNCTIONS
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1994) #K FOLD STRATIFIED TO HAVE SAME TARGET DISTRIBUTION IN ALL SPLITS
model = XGBClassifier()

scoring = {'accuracy': 'accuracy',
           'f1_macro':'f1_macro'}

param_grid = {
    'booster':['gbtree','dart'],
    'max_depth': [5,10],
    'eta':[0.01],
    # 'alpha':[0.1],
    # 'lambda':[1],
    }

grid_search = GridSearchCV(estimator=model, param_grid=param_grid,scoring=scoring, cv=skf, refit='accuracy', return_train_score=True)
grid_search.fit(X, y)

cv_results,best_model=F1_Modelling_Extra_Functions.grid_search_show_results(gs=grid_search,
                                                                            X_df=X,
                                                                            feature_importance_num_features=15,
                                                                            figuresize=(15,5))
# Out:
# c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# Best Estimator:  XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.01, eval_metric=None,
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)
# Best Score:  0.6208725330915229

# %%
# Try model in test set
y_pred = best_model.predict(X_test)

# Metrics
test_accuracy = accuracy_score(y_test+1, y_pred+1)
test_f1 = f1_score(y_test+1, y_pred+1, average='macro')

# Print the results
print("Accuracy: ",test_accuracy)
print("F1 Score: ",test_f1)

F1_Modelling_Extra_Functions.classification_test_results(y_test+1,y_pred+1,figuresize=(8,8)) #confusion matrix and classification report
# Out:
# Accuracy:  0.603448275862069
# F1 Score:  0.2700073964497041
#               precision    recall  f1-score   support
#
#            1       0.68      0.78      0.72       186
#            2       0.40      0.32      0.36        94
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.60       290
#    macro avg       0.27      0.27      0.27       290
# weighted avg       0.56      0.60      0.58       290

# %% [markdown]
# ##### 5. MLP

# %%
# SPLIT TRAIN, VALIDATION AND TEST DFs
# I want to predict with the final_position of the last F1 rounds
EXCLUDED_COLS=['Total_Duration_Pits_milliseconds', 'Min_Duration_Pits_milliseconds','Avg_Duration_Pits_milliseconds', 'Max_Duration_Pits_milliseconds','Avg_PitStop_Lap_number', 'Min_PitStop_Lap_number',
       'Max_PitStop_Lap_number', 'pit_stop_lap_number_1','pit_stop_lap_number_2', 'pit_stop_lap_number_3','pit_stop_lap_number_4', 'pit_stop_duration_in_milliseconds_1','pit_stop_duration_in_milliseconds_2','pit_stop_duration_in_milliseconds_3','pit_stop_duration_in_milliseconds_4','season','round',
       'airtemp', 'humidity', 'pressure','rainfall', 'tracktemp', 'winddirection', 'windspeed','season-round-event','season-round-driverid', 'racename', 'circuit.circuitname','circuit.location.country', 'date', 'season-round', 'circuit.circuitid',
       'driverid', 'driver.code', 'constructor.name', 'driver', 'compound','event','compound_cat','drivernumber','tyrelife']
TEST_SEGMENTS=np.sort(PitsDF_RACE_DRIVER_LEVEL["season-round"].unique())[-15:]
TEST_DF=PitsDF_RACE_DRIVER_LEVEL[PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)
TRAINING_VALIDATION_DF=PitsDF_RACE_DRIVER_LEVEL[~PitsDF_RACE_DRIVER_LEVEL["season-round"].isin(TEST_SEGMENTS)].drop(columns=EXCLUDED_COLS)

print("Test DF:",len(TEST_DF))
print("Train Validation DF:",len(TRAINING_VALIDATION_DF))

TARGET='Total_Num_Pits'
X = TRAINING_VALIDATION_DF.drop(columns=[TARGET])
y = TRAINING_VALIDATION_DF[TARGET]-1

X_test = TEST_DF.drop(columns=[TARGET])
y_test = TEST_DF[TARGET]-1

scaler = preprocessing.StandardScaler()
X_SCALED = scaler.fit_transform(X)
X_test_SCALED = scaler.transform(X_test)
# Out:
# Test DF: 290
# Train Validation DF: 1994

# %%
#  MLP structure to go through cross validation
def create_mlp(learning_rate=0.001, units_d1=64, units_d2=32,drop_rate=0.3):
    model = Sequential()
    model.add(Dense(units=units_d1, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dropout(drop_rate))
    # model.add(Dense(units=units_d2, activation='relu'))
    # model.add(Dropout(drop_rate))
    model.add(Dense(PitsDF_RACE_DRIVER_LEVEL[TARGET].nunique(), activation='softmax'))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# CROSS VALIDATION AND HYPERPARAMETER TUNING
# RESULTS SHOWN WITH PERSONALIZED FUNCTIONS
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1994) #K FOLD STRATIFIED TO HAVE SAME TARGET DISTRIBUTION IN ALL SPLITS
model = KerasClassifier(model=create_mlp, verbose=0)

scoring = {'accuracy': 'accuracy',
           'f1_macro':'f1_macro'}

param_grid = {
    'epochs': [100],
    'batch_size': [360]
}

results=pd.DataFrame()
history_test=pd.DataFrame()

# I try different learning rates and number of neurons
for lr in [0.0005]:
    for u1 in [6,8,10,12]:
        for u2 in [0]:
            #CV
            model = KerasClassifier(model=create_mlp(learning_rate=lr,units_d1=u1,units_d2=u2), verbose=0)
            grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=skf, scoring=scoring, refit='f1_macro')
            grid_search.fit(X_SCALED, y)
            to_Add=pd.DataFrame({"LR":[lr],"U1":[u1],"U2":[u2],
                                 "Best_CV_epochs":[grid_search.best_params_["epochs"]],
                                 "Best_CV_batch_size":[grid_search.best_params_["batch_size"]],
                                 "BestScore":grid_search.best_score_,"BestModel":grid_search.best_estimator_})
            results=pd.concat([results,to_Add],ignore_index=True)
            print(">>>>>>>>>> LR:",lr," | U1:",u1," | U2:",u2," | Best CV HP:",grid_search.best_params_," | BestScore:",grid_search.best_score_)
            #EVALUATION
            history = grid_search.best_estimator_.fit(X_SCALED, y, validation_data=(X_test_SCALED, y_test))
            history_toAdd=pd.DataFrame(history.history_)
            history_toAdd["LR"]=lr
            history_toAdd["U1"]=u1
            history_toAdd["U2"]=u2
            history_test=pd.concat([history_toAdd,history_test])
            F1_Modelling_Extra_Functions.MLP_test_results(history_toAdd,figuresize=(6,3)) #plots
# Out:
# >>>>>>>>>> LR: 0.0005  | U1: 6  | U2: 0  | Best CV HP: {'batch_size': 360, 'epochs': 100}  | BestScore: 0.3162290926311824
# >>>>>>>>>> LR: 0.0005  | U1: 8  | U2: 0  | Best CV HP: {'batch_size': 360, 'epochs': 100}  | BestScore: 0.2760063851937584
# >>>>>>>>>> LR: 0.0005  | U1: 10  | U2: 0  | Best CV HP: {'batch_size': 360, 'epochs': 100}  | BestScore: 0.2996500774855459
# >>>>>>>>>> LR: 0.0005  | U1: 12  | U2: 0  | Best CV HP: {'batch_size': 360, 'epochs': 100}  | BestScore: 0.32027167172019805

# %%
# Try model in test set
y_pred = results[results["U1"]==12].reset_index()["BestModel"][0].predict(X_test_SCALED)

# Metrics
test_accuracy = accuracy_score(y_test+1, y_pred+1)
test_f1 = f1_score(y_test+1, y_pred+1, average='macro')

# Print the results
print("Accuracy: ",test_accuracy)
print("F1 Score: ",test_f1)

F1_Modelling_Extra_Functions.classification_test_results(y_test+1,y_pred+1,figuresize=(8,8)) #confusion matrix and classification report
# Out:
# Accuracy:  0.596551724137931
# F1 Score:  0.2860382996061388
#               precision    recall  f1-score   support
#
#            1       0.70      0.69      0.69       186
#            2       0.43      0.48      0.45        94
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.60       290
#    macro avg       0.28      0.29      0.29       290
# weighted avg       0.59      0.60      0.59       290
